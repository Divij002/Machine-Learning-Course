# %% [markdown]
# # Recommendation System
# Can be categorized into two parts
# ### 1. Content based RS : Item-based filtering -- using this for our project
#     user 1 likes a,b,c.
#     user 2 likes a,b.
#     user 3 likes a
#     Hence
#     b will be recommended to user 3
#
#
# ### 2. Collaborative filtering -- better for real life scenarios/marketing
#     Notice user behaviour
#     user 1 likes pizza,pasta,coke
#     user 2 likes pizza,pasta
#     coke will be recommended to user 2

# %% [markdown]
# # Movie Recommendation project
#
# RS : Content based recommendation system
#
# Dataset : Movielens 100k

# %%
#Importing Libraries
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Setting up database

# %%
#Get the Dataset -- it is not csv but a tsv file 
df = pd.read_csv("ml-100k/u.data",sep='\t', header=None, names=['user_id', 'item_id', 'rating', 'timestamp'])
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596

# %%
print(df.shape)
print("unique users : ",df['user_id'].nunique(),"\n unique movies: " ,df['item_id'].nunique())
# Out:
# (100000, 4)
# unique users :  943
#  unique movies:  1682

# %%
#We dont know which item id corresponds to which movie
#So we will get that data from u.item file
movie_titles = pd.read_csv("ml-100k/u.item",sep='|', header=None, names=['item_id', 'title'], usecols=[0,1], encoding='latin-1')
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
#Merging the movie titles with the ratings data 
df = pd.merge(df, movie_titles, on='item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp                       title
# 0      196      242       3  881250949                Kolya (1996)
# 1      186      302       3  891717742    L.A. Confidential (1997)
# 2       22      377       1  878887116         Heavyweights (1994)
# 3      244       51       2  880606923  Legends of the Fall (1994)
# 4      166      346       1  886397596         Jackie Brown (1997)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Average Rating of Movies
df.groupby('title').mean()['rating'].sort_values(ascending=False)
# Out:
# title
# They Made Me a Criminal (1939)                  5.0
# Marlene Dietrich: Shadow and Light (1996)       5.0
# Saint of Fort Washington, The (1993)            5.0
# Someone Else's America (1995)                   5.0
# Star Kid (1997)                                 5.0
#                                                ...
# Eye of Vichy, The (Oeil de Vichy, L') (1993)    1.0
# King of New York (1990)                         1.0
# Touki Bouki (Journey of the Hyena) (1973)       1.0
# Bloody Child, The (1996)                        1.0
# Crude Oasis, The (1995)                         1.0
# Name: rating, Length: 1664, dtype: float64

# %%
#Most rated movies
df.groupby('title').count()['rating'].sort_values(ascending=False)
# Out:
# title
# Star Wars (1977)                      583
# Contact (1997)                        509
# Fargo (1996)                          508
# Return of the Jedi (1983)             507
# Liar Liar (1997)                      485
#                                      ...
# Great Day in Harlem, A (1994)           1
# Other Voices, Other Rooms (1997)        1
# Good Morning (1971)                     1
# Girls Town (1996)                       1
# Á köldum klaka (Cold Fever) (1994)      1
# Name: rating, Length: 1664, dtype: int64

# %%
#Creating dataframes of ratings and number of ratings
ratings = pd.DataFrame(df.groupby('title').mean()['rating'])
ratings['num of ratings'] = pd.DataFrame(df.groupby('title').count()['rating'])
ratings.sort_values('num of ratings', ascending=False).head()
# Out:
#                              rating  num of ratings
# title
# Star Wars (1977)           4.358491             583
# Contact (1997)             3.803536             509
# Fargo (1996)               4.155512             508
# Return of the Jedi (1983)  4.007890             507
# Liar Liar (1997)           3.156701             485

# %%
#Plotting the data
plt.figure(figsize=(10,4))
plt.hist(ratings['num of ratings'],bins=70)
plt.xlabel('Number of Ratings')
plt.ylabel('Count of Movies')
plt.show()

# %%
#Plotting Ratings
plt.hist(ratings['rating'],bins=70)
plt.xlabel('Rating')    
plt.ylabel('Count of Movies')
plt.show()

# %%
#Jointplot of number of ratings vs ratings
sns.jointplot(x='rating', y='num of ratings', data=ratings, alpha=0.5)

# %% [markdown]
# ## Building Reccomendation system

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp                       title
# 0      196      242       3  881250949                Kolya (1996)
# 1      186      302       3  891717742    L.A. Confidential (1997)
# 2       22      377       1  878887116         Heavyweights (1994)
# 3      244       51       2  880606923  Legends of the Fall (1994)
# 4      166      346       1  886397596         Jackie Brown (1997)

# %%
moviemat = df.pivot_table(index='user_id', columns='title', values='rating')
moviemat.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
ratings.sort_values('num of ratings', ascending=False).head(10)
# Out:
#                                  rating  num of ratings
# title
# Star Wars (1977)               4.358491             583
# Contact (1997)                 3.803536             509
# Fargo (1996)                   4.155512             508
# Return of the Jedi (1983)      4.007890             507
# Liar Liar (1997)               3.156701             485
# English Patient, The (1996)    3.656965             481
# Scream (1996)                  3.441423             478
# Toy Story (1995)               3.878319             452
# Air Force One (1997)           3.631090             431
# Independence Day (ID4) (1996)  3.438228             429

# %%
starwars_user_ratings = moviemat['Star Wars (1977)']
starwars_user_ratings.head()
# Out:
# user_id
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    4.0
# Name: Star Wars (1977), dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_starwars
# Out:
# title
# 'Til There Was You (1997)                0.872872
# 1-900 (1994)                            -0.645497
# 101 Dalmatians (1996)                    0.211132
# 12 Angry Men (1957)                      0.184289
# 187 (1997)                               0.027398
#                                            ...
# Young Guns II (1990)                     0.228615
# Young Poisoner's Handbook, The (1995)   -0.007374
# Zeus and Roxanne (1997)                  0.818182
# unknown                                  0.723123
# Á köldum klaka (Cold Fever) (1994)            NaN
# Length: 1664, dtype: float64

# %%
corr_starwars = pd.DataFrame(similar_to_starwars, columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                            Correlation
# title
# 'Til There Was You (1997)     0.872872
# 1-900 (1994)                 -0.645497
# 101 Dalmatians (1996)         0.211132
# 12 Angry Men (1957)           0.184289
# 187 (1997)                    0.027398

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                            Correlation  num of ratings
# title
# 'Til There Was You (1997)     0.872872               9
# 1-900 (1994)                 -0.645497               5
# 101 Dalmatians (1996)         0.211132             109
# 12 Angry Men (1957)           0.184289             125
# 187 (1997)                    0.027398              41

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation', ascending=False).head()
# Out:
#                                                     Correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.747981
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
#
#                                                     num of ratings
# title
# Star Wars (1977)                                               583
# Empire Strikes Back, The (1980)                                367
# Return of the Jedi (1983)                                      507
# Raiders of the Lost Ark (1981)                                 420
# Austin Powers: International Man of Mystery (1997)             130

# %% [markdown]
# ### Predict Function

# %%
def predict_movies(movie_name):
    movie_user_ratings = moviemat[movie_name]
    similar_to_movie = moviemat.corrwith(movie_user_ratings)
    corr_movie = pd.DataFrame(similar_to_movie, columns=['Correlation'])
    corr_movie.dropna(inplace=True)
    corr_movie = corr_movie.join(ratings['num of ratings'])
    predictions = corr_movie[corr_movie['num of ratings']>100].sort_values('Correlation', ascending=False).head()
    return predictions

# %%
predict_movies("Titanic (1997)")
# Out:
#                               Correlation  num of ratings
# title
# Titanic (1997)                   1.000000             350
# River Wild, The (1994)           0.497600             146
# Abyss, The (1989)                0.472103             151
# Bram Stoker's Dracula (1992)     0.443560             120
# True Lies (1994)                 0.435104             208
